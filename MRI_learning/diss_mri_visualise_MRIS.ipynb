# %%
# Import all the necessary packages
import numpy as np
import nibabel as nib
import itk
import itkwidgets
from ipywidgets import interact, interactive, IntSlider, ToggleButtons
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('darkgrid')

# %%
import torch 
print(torch.backends.mps.is_available())
# Out:
# True

# %%
data_root_path = './data/MINI_DATA'
path = '../../../../../../../Documents/MINI_DATA_FOR_PLAY/MINI_PROCESSED'

# %%
example_image_path = './data/MINI_DATA/MINI_ORIGINAL/IXI/t2/IXI1.nii.gz'

# %%
def viz_single_slice(image_path, layer):
    image_obj = nib.load(image_path)
    # Extract data as numpy ndarray
    image_data = image_obj.get_fdata()
    print('image_data pixels data type: ',  image_data.dtype)
    print('image_data type: ',  type(image_data))
    print('image_obj type: ',  type(image_obj))
    height, width, depth = image_data.shape
    print(f"({height}, {width}, {depth})")
    print(f"Plotting Layer {layer} of Image")
    
    plt.figure(figsize=(3, 3))
    plt.imshow(image_data[:, :, layer], cmap='gray')
    plt.title(f"{image_path}\nLayer: {layer}")
    plt.axis('off')
    plt.show()

# %%
viz_single_slice(example_image_path, 42)
# Out:
# image_data pixels data type:  float64
# image_data type:  <class 'numpy.ndarray'>
# image_obj type:  <class 'nibabel.nifti1.Nifti1Image'>
# (256, 256, 130)
# Plotting Layer 42 of Image

# %%
def explore_3dimage(image_data, layer, image_path):
    plt.figure(figsize=(10, 5))
    plt.imshow(image_data[:, :, layer], cmap='gray');
    plt.title(f'{image_path[2:-7]}', fontsize=20)
    plt.axis('off')
    return layer

def viz_interactive_3D_image(image_path):
    image_obj = nib.load(image_path)
    image_data = image_obj.get_fdata()
    print('image_data pixels data type: ',  image_data.dtype)
    print('image_data type: ',  type(image_data))
    print('image_obj type: ',  type(image_obj))
    height, width, depth = image_data.shape
    print(f"({height}, {width}, {depth})")
    interact(lambda layer: explore_3dimage(image_data, layer, image_path), layer=(0, image_data.shape[2] - 1))

# %%
viz_interactive_3D_image(example_image_path)
# Out:
# image_data pixels data type:  float64
# image_data type:  <class 'numpy.ndarray'>
# image_obj type:  <class 'nibabel.nifti1.Nifti1Image'>
# (256, 256, 130)
# interactive(children=(IntSlider(value=64, description='layer', max=129), Output()), _dom_classes=('widget-inte…

# %%
example_image_path = './data/MINI_DATA/MINI_ORIGINAL/Brats21/t2/Brats1.nii.gz'
viz_interactive_3D_image(example_image_path)
# Out:
# image_data pixels data type:  float64
# image_data type:  <class 'numpy.ndarray'>
# image_obj type:  <class 'nibabel.nifti1.Nifti1Image'>
# (240, 240, 155)
# interactive(children=(IntSlider(value=77, description='layer', max=154), Output()), _dom_classes=('widget-inte…

# %%
example_image_path = './data/MINI_DATA/MINI_ORIGINAL/Brats21/seg/Brats1_seg.nii.gz'
viz_interactive_3D_image(example_image_path)
# Out:
# image_data pixels data type:  float64
# image_data type:  <class 'numpy.ndarray'>
# image_obj type:  <class 'nibabel.nifti1.Nifti1Image'>
# (240, 240, 155)
# interactive(children=(IntSlider(value=77, description='layer', max=154), Output()), _dom_classes=('widget-inte…

# %%
example_image_path = './data/MINI_DATA/MINI_ORIGINAL/IXI/t2/IXI1.nii.gz'
viz_interactive_3D_image(example_image_path)
# Out:
# image_data pixels data type:  float64
# image_data type:  <class 'numpy.ndarray'>
# image_obj type:  <class 'nibabel.nifti1.Nifti1Image'>
# (256, 256, 130)
# interactive(children=(IntSlider(value=64, description='layer', max=129), Output()), _dom_classes=('widget-inte…

# %%
example_image_path = './data/MINI_DATA/MINI_ORIGINAL/MSLUB/t2/MSLUB1.nii.gz'
viz_interactive_3D_image(example_image_path)
# Out:
# image_data pixels data type:  float64
# image_data type:  <class 'numpy.ndarray'>
# image_obj type:  <class 'nibabel.nifti1.Nifti1Image'>
# (354, 384, 156)
# interactive(children=(IntSlider(value=77, description='layer', max=155), Output()), _dom_classes=('widget-inte…

# %%
example_image_path = './data/MINI_DATA/MINI_ORIGINAL/MSLUB/seg/MSLUB1_seg.nii.gz'
viz_interactive_3D_image(example_image_path)
# Out:
# image_data pixels data type:  float64
# image_data type:  <class 'numpy.ndarray'>
# image_obj type:  <class 'nibabel.nifti1.Nifti1Image'>
# (192, 512, 512)
# interactive(children=(IntSlider(value=255, description='layer', max=511), Output()), _dom_classes=('widget-int…

# %% [markdown]
# PROCESSED RESAMPLED

# %%
example_image_path = '../../../../../../../Documents/MINI_DATA_FOR_PLAY/MINI_PROCESSED/v1resampled/IXI/t2/IXI1.nii.gz_t2.nii.gz'
viz_interactive_3D_image(example_image_path)
# Out:
# image_data pixels data type:  float64
# image_data type:  <class 'numpy.ndarray'>
# image_obj type:  <class 'nibabel.nifti1.Nifti1Image'>
# (240, 240, 163)
# interactive(children=(IntSlider(value=81, description='layer', max=162), Output()), _dom_classes=('widget-inte…

# %%
example_image_path = '../../../../../../../Documents/MINI_DATA_FOR_PLAY/MINI_PROCESSED/v1resampled/MSLUB/t2/MSLUB1.nii.gz_t2.nii.gz'
viz_interactive_3D_image(example_image_path)
# Out:
# image_data pixels data type:  float64
# image_data type:  <class 'numpy.ndarray'>
# image_obj type:  <class 'nibabel.nifti1.Nifti1Image'>
# (203, 220, 129)
# interactive(children=(IntSlider(value=64, description='layer', max=128), Output()), _dom_classes=('widget-inte…

# %%
example_image_path = '../../../../../../../Documents/MINI_DATA_FOR_PLAY/MINI_PROCESSED/v1resampled/Brats21/t2/Brats1.nii.gz_t2.nii.gz'
viz_interactive_3D_image(example_image_path)
# Out:
# image_data pixels data type:  float64
# image_data type:  <class 'numpy.ndarray'>
# image_obj type:  <class 'nibabel.nifti1.Nifti1Image'>
# (240, 240, 155)
# interactive(children=(IntSlider(value=77, description='layer', max=154), Output()), _dom_classes=('widget-inte…

# %% [markdown]
# ***

# %% [markdown]
# PROCESSED SKULLSTRIPPED

# %%
example_image_path = '../../../../../../../Documents/MINI_DATA_FOR_PLAY/MINI_PROCESSED/v2skullstripped/IXI/mask/IXI1.nii.gz_mask.nii.gz'
viz_interactive_3D_image(example_image_path)
example_image_path = '../../../../../../../Documents/MINI_DATA_FOR_PLAY/MINI_PROCESSED/v2skullstripped/IXI/t2/IXI1.nii.gz_t2.nii.gz'
viz_interactive_3D_image(example_image_path)
# Out:
# image_data pixels data type:  float64
# image_data type:  <class 'numpy.ndarray'>
# image_obj type:  <class 'nibabel.nifti1.Nifti1Image'>
# (240, 240, 163)
# interactive(children=(IntSlider(value=81, description='layer', max=162), Output()), _dom_classes=('widget-inte…
# image_data pixels data type:  float64
# image_data type:  <class 'numpy.ndarray'>
# image_obj type:  <class 'nibabel.nifti1.Nifti1Image'>
# (240, 240, 163)
# interactive(children=(IntSlider(value=81, description='layer', max=162), Output()), _dom_classes=('widget-inte…

# %%
example_image_path = '../../../../../../../Documents/MINI_DATA_FOR_PLAY/MINI_PROCESSED/v2skullstripped/MSLUB/mask/MSLUB1.nii.gz_mask.nii.gz'
viz_interactive_3D_image(example_image_path)
example_image_path = '../../../../../../../Documents/MINI_DATA_FOR_PLAY/MINI_PROCESSED/v2skullstripped/MSLUB/seg/MSLUB1.nii.gz_seg.nii.gz'
viz_interactive_3D_image(example_image_path)
example_image_path = '../../../../../../../Documents/MINI_DATA_FOR_PLAY/MINI_PROCESSED/v2skullstripped/MSLUB/t2/MSLUB1.nii.gz_t2.nii.gz'
viz_interactive_3D_image(example_image_path)
# Out:
# image_data pixels data type:  float64
# image_data type:  <class 'numpy.ndarray'>
# image_obj type:  <class 'nibabel.nifti1.Nifti1Image'>
# (203, 220, 129)
# interactive(children=(IntSlider(value=64, description='layer', max=128), Output()), _dom_classes=('widget-inte…
# image_data pixels data type:  float64
# image_data type:  <class 'numpy.ndarray'>
# image_obj type:  <class 'nibabel.nifti1.Nifti1Image'>
# (192, 512, 512)
# interactive(children=(IntSlider(value=255, description='layer', max=511), Output()), _dom_classes=('widget-int…
# image_data pixels data type:  float64
# image_data type:  <class 'numpy.ndarray'>
# image_obj type:  <class 'nibabel.nifti1.Nifti1Image'>
# (203, 220, 129)
# interactive(children=(IntSlider(value=64, description='layer', max=128), Output()), _dom_classes=('widget-inte…

# %%
example_image_path = '../../../../../../../Documents/MINI_DATA_FOR_PLAY/MINI_PROCESSED/v2skullstripped/Brats21/mask/Brats1.nii.gz_mask.nii.gz'
viz_interactive_3D_image(example_image_path)
example_image_path = '../../../../../../../Documents/MINI_DATA_FOR_PLAY/MINI_PROCESSED/v2skullstripped/Brats21/seg/Brats1.nii.gz_seg.nii.gz'
viz_interactive_3D_image(example_image_path)
example_image_path = '../../../../../../../Documents/MINI_DATA_FOR_PLAY/MINI_PROCESSED/v2skullstripped/Brats21/t2/Brats1.nii.gz_t2.nii.gz'
viz_interactive_3D_image(example_image_path)
# Out:
# image_data pixels data type:  float64
# image_data type:  <class 'numpy.ndarray'>
# image_obj type:  <class 'nibabel.nifti1.Nifti1Image'>
# (240, 240, 155)
# interactive(children=(IntSlider(value=77, description='layer', max=154), Output()), _dom_classes=('widget-inte…
# image_data pixels data type:  float64
# image_data type:  <class 'numpy.ndarray'>
# image_obj type:  <class 'nibabel.nifti1.Nifti1Image'>
# (240, 240, 155)
# interactive(children=(IntSlider(value=77, description='layer', max=154), Output()), _dom_classes=('widget-inte…
# image_data pixels data type:  float64
# image_data type:  <class 'numpy.ndarray'>
# image_obj type:  <class 'nibabel.nifti1.Nifti1Image'>
# (240, 240, 155)
# interactive(children=(IntSlider(value=77, description='layer', max=154), Output()), _dom_classes=('widget-inte…

# %% [markdown]
# ***

# %% [markdown]
# PROCESSED - REGESTERED

# %%
example_image_path = '../../../../../../../Documents/MINI_DATA_FOR_PLAY/MINI_PROCESSED/v3registered_non_iso/IXI/mask/IXI1.nii.gz_mask.nii.gz'
viz_interactive_3D_image(example_image_path)
example_image_path = '../../../../../../../Documents/MINI_DATA_FOR_PLAY/MINI_PROCESSED/v3registered_non_iso/IXI/t2/IXI1.nii.gz_t2.nii.gz'
viz_interactive_3D_image(example_image_path)
# Out:
# image_data pixels data type:  float64
# image_data type:  <class 'numpy.ndarray'>
# image_obj type:  <class 'nibabel.nifti1.Nifti1Image'>
# (240, 240, 155)
# interactive(children=(IntSlider(value=77, description='layer', max=154), Output()), _dom_classes=('widget-inte…
# image_data pixels data type:  float64
# image_data type:  <class 'numpy.ndarray'>
# image_obj type:  <class 'nibabel.nifti1.Nifti1Image'>
# (240, 240, 155)
# interactive(children=(IntSlider(value=77, description='layer', max=154), Output()), _dom_classes=('widget-inte…

# %%
example_image_path = '../../../../../../../Documents/MINI_DATA_FOR_PLAY/MINI_PROCESSED/v3registered_non_iso/MSLUB/mask/MSLUB1.nii.gz_mask.nii.gz'
viz_interactive_3D_image(example_image_path)
example_image_path = '../../../../../../../Documents/MINI_DATA_FOR_PLAY/MINI_PROCESSED/v3registered_non_iso/MSLUB/seg/MSLUB1.nii.gz_seg.nii.gz'
viz_interactive_3D_image(example_image_path)
example_image_path = '../../../../../../../Documents/MINI_DATA_FOR_PLAY/MINI_PROCESSED/v3registered_non_iso/MSLUB/t2/MSLUB1.nii.gz_t2.nii.gz'
viz_interactive_3D_image(example_image_path)
# Out:
# image_data pixels data type:  float64
# image_data type:  <class 'numpy.ndarray'>
# image_obj type:  <class 'nibabel.nifti1.Nifti1Image'>
# (240, 240, 155)
# interactive(children=(IntSlider(value=77, description='layer', max=154), Output()), _dom_classes=('widget-inte…
# image_data pixels data type:  float64
# image_data type:  <class 'numpy.ndarray'>
# image_obj type:  <class 'nibabel.nifti1.Nifti1Image'>
# (240, 240, 155)
# interactive(children=(IntSlider(value=77, description='layer', max=154), Output()), _dom_classes=('widget-inte…
# image_data pixels data type:  float64
# image_data type:  <class 'numpy.ndarray'>
# image_obj type:  <class 'nibabel.nifti1.Nifti1Image'>
# (240, 240, 155)
# interactive(children=(IntSlider(value=77, description='layer', max=154), Output()), _dom_classes=('widget-inte…

# %%
example_image_path = '../../../../../../../Documents/MINI_DATA_FOR_PLAY/MINI_PROCESSED/v3registered_non_iso/Brats21/mask/Brats1.nii.gz_mask.nii.gz'
viz_interactive_3D_image(example_image_path)
example_image_path = '../../../../../../../Documents/MINI_DATA_FOR_PLAY/MINI_PROCESSED/v3registered_non_iso/Brats21/seg/Brats1.nii.gz_seg.nii.gz'
viz_interactive_3D_image(example_image_path)
example_image_path = '../../../../../../../Documents/MINI_DATA_FOR_PLAY/MINI_PROCESSED/v3registered_non_iso/Brats21/t2/Brats1.nii.gz_t2.nii.gz'
viz_interactive_3D_image(example_image_path)
# Out:
# image_data pixels data type:  float64
# image_data type:  <class 'numpy.ndarray'>
# image_obj type:  <class 'nibabel.nifti1.Nifti1Image'>
# (240, 240, 155)
# interactive(children=(IntSlider(value=77, description='layer', max=154), Output()), _dom_classes=('widget-inte…
# image_data pixels data type:  float64
# image_data type:  <class 'numpy.ndarray'>
# image_obj type:  <class 'nibabel.nifti1.Nifti1Image'>
# (240, 240, 155)
# interactive(children=(IntSlider(value=77, description='layer', max=154), Output()), _dom_classes=('widget-inte…
# image_data pixels data type:  float64
# image_data type:  <class 'numpy.ndarray'>
# image_obj type:  <class 'nibabel.nifti1.Nifti1Image'>
# (240, 240, 155)
# interactive(children=(IntSlider(value=77, description='layer', max=154), Output()), _dom_classes=('widget-inte…

# %% [markdown]
# ***

# %%
example_image_path = '../../../../../../../Documents/MINI_DATA_FOR_PLAY/MINI_PROCESSED/v3registered_non_iso_cut/IXI/mask/IXI1.nii.gz_mask.nii.gz'
viz_interactive_3D_image(example_image_path)
example_image_path = '../../../../../../../Documents/MINI_DATA_FOR_PLAY/MINI_PROCESSED/v3registered_non_iso_cut/IXI/t2/IXI1.nii.gz_t2.nii.gz'
viz_interactive_3D_image(example_image_path)
# Out:
# image_data pixels data type:  float64
# image_data type:  <class 'numpy.ndarray'>
# image_obj type:  <class 'nibabel.nifti1.Nifti1Image'>
# (138, 173, 137)
# interactive(children=(IntSlider(value=68, description='layer', max=136), Output()), _dom_classes=('widget-inte…
# image_data pixels data type:  float64
# image_data type:  <class 'numpy.ndarray'>
# image_obj type:  <class 'nibabel.nifti1.Nifti1Image'>
# (138, 173, 137)
# interactive(children=(IntSlider(value=68, description='layer', max=136), Output()), _dom_classes=('widget-inte…

# %%
example_image_path = '../../../../../../../Documents/MINI_DATA_FOR_PLAY/MINI_PROCESSED/v3registered_non_iso_cut/MSLUB/mask/MSLUB1.nii.gz_mask.nii.gz'
viz_interactive_3D_image(example_image_path)
example_image_path = '../../../../../../../Documents/MINI_DATA_FOR_PLAY/MINI_PROCESSED/v3registered_non_iso_cut/MSLUB/seg/MSLUB1.nii.gz_seg.nii.gz'
viz_interactive_3D_image(example_image_path)
example_image_path = '../../../../../../../Documents/MINI_DATA_FOR_PLAY/MINI_PROCESSED/v3registered_non_iso_cut/MSLUB/t2/MSLUB1.nii.gz_t2.nii.gz'
viz_interactive_3D_image(example_image_path)
# Out:
# image_data pixels data type:  float64
# image_data type:  <class 'numpy.ndarray'>
# image_obj type:  <class 'nibabel.nifti1.Nifti1Image'>
# (134, 171, 125)
# interactive(children=(IntSlider(value=62, description='layer', max=124), Output()), _dom_classes=('widget-inte…
# image_data pixels data type:  float64
# image_data type:  <class 'numpy.ndarray'>
# image_obj type:  <class 'nibabel.nifti1.Nifti1Image'>
# (134, 171, 125)
# interactive(children=(IntSlider(value=62, description='layer', max=124), Output()), _dom_classes=('widget-inte…
# image_data pixels data type:  float64
# image_data type:  <class 'numpy.ndarray'>
# image_obj type:  <class 'nibabel.nifti1.Nifti1Image'>
# (134, 171, 125)
# interactive(children=(IntSlider(value=62, description='layer', max=124), Output()), _dom_classes=('widget-inte…

# %%
example_image_path = '../../../../../../../Documents/MINI_DATA_FOR_PLAY/MINI_PROCESSED/v3registered_non_iso_cut/Brats21/mask/Brats1.nii.gz_mask.nii.gz'
viz_interactive_3D_image(example_image_path)
example_image_path = '../../../../../../../Documents/MINI_DATA_FOR_PLAY/MINI_PROCESSED/v3registered_non_iso_cut/Brats21/seg/Brats1.nii.gz_seg.nii.gz'
viz_interactive_3D_image(example_image_path)
example_image_path = '../../../../../../../Documents/MINI_DATA_FOR_PLAY/MINI_PROCESSED/v3registered_non_iso_cut/Brats21/t2/Brats1.nii.gz_t2.nii.gz'
viz_interactive_3D_image(example_image_path)
# Out:
# image_data pixels data type:  float64
# image_data type:  <class 'numpy.ndarray'>
# image_obj type:  <class 'nibabel.nifti1.Nifti1Image'>
# (141, 172, 142)
# interactive(children=(IntSlider(value=70, description='layer', max=141), Output()), _dom_classes=('widget-inte…
# image_data pixels data type:  float64
# image_data type:  <class 'numpy.ndarray'>
# image_obj type:  <class 'nibabel.nifti1.Nifti1Image'>
# (141, 172, 142)
# interactive(children=(IntSlider(value=70, description='layer', max=141), Output()), _dom_classes=('widget-inte…
# image_data pixels data type:  float64
# image_data type:  <class 'numpy.ndarray'>
# image_obj type:  <class 'nibabel.nifti1.Nifti1Image'>
# (141, 172, 142)
# interactive(children=(IntSlider(value=70, description='layer', max=141), Output()), _dom_classes=('widget-inte…

# %% [markdown]
# ***

# %%
example_image_path = '../../../../../../../Documents/MINI_DATA_FOR_PLAY/MINI_PROCESSED/v4correctedN4_non_iso_cut/IXI/mask/IXI1.nii.gz_mask.nii.gz'
viz_interactive_3D_image(example_image_path)
example_image_path = '../../../../../../../Documents/MINI_DATA_FOR_PLAY/MINI_PROCESSED/v4correctedN4_non_iso_cut/IXI/t2/IXI1.nii.gz_t2.nii.gz'
viz_interactive_3D_image(example_image_path)
# Out:
# image_data pixels data type:  float64
# image_data type:  <class 'numpy.ndarray'>
# image_obj type:  <class 'nibabel.nifti1.Nifti1Image'>
# (138, 173, 137)
# interactive(children=(IntSlider(value=68, description='layer', max=136), Output()), _dom_classes=('widget-inte…
# image_data pixels data type:  float64
# image_data type:  <class 'numpy.ndarray'>
# image_obj type:  <class 'nibabel.nifti1.Nifti1Image'>
# (138, 173, 137)
# interactive(children=(IntSlider(value=68, description='layer', max=136), Output()), _dom_classes=('widget-inte…

# %%
example_image_path = '../../../../../../../Documents/MINI_DATA_FOR_PLAY/MINI_PROCESSED/v4correctedN4_non_iso_cut/MSLUB/mask/MSLUB1.nii.gz_mask.nii.gz'
viz_interactive_3D_image(example_image_path)
example_image_path = '../../../../../../../Documents/MINI_DATA_FOR_PLAY/MINI_PROCESSED/v4correctedN4_non_iso_cut/MSLUB/seg/MSLUB1.nii.gz_seg.nii.gz'
viz_interactive_3D_image(example_image_path)
example_image_path = '../../../../../../../Documents/MINI_DATA_FOR_PLAY/MINI_PROCESSED/v4correctedN4_non_iso_cut/MSLUB/t2/MSLUB1.nii.gz_t2.nii.gz'
viz_interactive_3D_image(example_image_path)
# Out:
# image_data pixels data type:  float64
# image_data type:  <class 'numpy.ndarray'>
# image_obj type:  <class 'nibabel.nifti1.Nifti1Image'>
# (134, 171, 125)
# interactive(children=(IntSlider(value=62, description='layer', max=124), Output()), _dom_classes=('widget-inte…
# image_data pixels data type:  float64
# image_data type:  <class 'numpy.ndarray'>
# image_obj type:  <class 'nibabel.nifti1.Nifti1Image'>
# (134, 171, 125)
# interactive(children=(IntSlider(value=62, description='layer', max=124), Output()), _dom_classes=('widget-inte…
# image_data pixels data type:  float64
# image_data type:  <class 'numpy.ndarray'>
# image_obj type:  <class 'nibabel.nifti1.Nifti1Image'>
# (134, 171, 125)
# interactive(children=(IntSlider(value=62, description='layer', max=124), Output()), _dom_classes=('widget-inte…

# %%
example_image_path = '../../../../../../../Documents/MINI_DATA_FOR_PLAY/MINI_PROCESSED/v4correctedN4_non_iso_cut/Brats21/mask/Brats1.nii.gz_mask.nii.gz'
viz_interactive_3D_image(example_image_path)
example_image_path = '../../../../../../../Documents/MINI_DATA_FOR_PLAY/MINI_PROCESSED/v4correctedN4_non_iso_cut/Brats21/seg/Brats1.nii.gz_seg.nii.gz'
viz_interactive_3D_image(example_image_path)
example_image_path = '../../../../../../../Documents/MINI_DATA_FOR_PLAY/MINI_PROCESSED/v4correctedN4_non_iso_cut/Brats21/t2/Brats1.nii.gz_t2.nii.gz'
viz_interactive_3D_image(example_image_path)
# Out:
# image_data pixels data type:  float64
# image_data type:  <class 'numpy.ndarray'>
# image_obj type:  <class 'nibabel.nifti1.Nifti1Image'>
# (141, 172, 142)
# interactive(children=(IntSlider(value=70, description='layer', max=141), Output()), _dom_classes=('widget-inte…
# image_data pixels data type:  float64
# image_data type:  <class 'numpy.ndarray'>
# image_obj type:  <class 'nibabel.nifti1.Nifti1Image'>
# (141, 172, 142)
# interactive(children=(IntSlider(value=70, description='layer', max=141), Output()), _dom_classes=('widget-inte…
# image_data pixels data type:  float64
# image_data type:  <class 'numpy.ndarray'>
# image_obj type:  <class 'nibabel.nifti1.Nifti1Image'>
# (141, 172, 142)
# interactive(children=(IntSlider(value=70, description='layer', max=141), Output()), _dom_classes=('widget-inte…
